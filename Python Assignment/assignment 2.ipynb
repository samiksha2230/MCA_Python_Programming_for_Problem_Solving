# %%
# Program to find probability of rolling a dice

print("Probability of each outcome when rolling a fair dice:")
total_outcomes = 6                # Dice has 6 faces

for face in range(1, 7):
    probability = 1/total_outcomes
    print(f"Probability of rolling {face}: {probability}")
# Out:
# Probability of each outcome when rolling a fair dice:
# Probability of rolling 1: 0.16666666666666666
# Probability of rolling 2: 0.16666666666666666
# Probability of rolling 3: 0.16666666666666666
# Probability of rolling 4: 0.16666666666666666
# Probability of rolling 5: 0.16666666666666666
# Probability of rolling 6: 0.16666666666666666
