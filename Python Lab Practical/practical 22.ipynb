# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

emp = pd.read_csv("C:/Users/samik/Downloads/employee_data.csv")
print(emp)
# Out:
#     Employee_ID    Name Department  Experience_Years  Salary  Age
# 0           501    John         IT                 5    65.0   28
# 1           502   Sarah         HR                 3    45.0   26
# 2           503    Mike         IT                 8    85.0   32
# 3           504    Lisa    Finance                 6    72.0   30
# 4           505     Tom         IT                 2    42.0   24
# 5           506    Emma         HR                 7    68.0   31
# 6           507   David    Finance                 4    58.0   27
# 7           508  Rachel         IT                10    95.0   35
# 8           509   Chris         HR                 5    55.0   29
# 9           510    Anna    Finance                 9    88.0   34
# 10          511   Peter         IT                 6    75.0   30
# 11          512   Julia         HR                 4    50.0   28
# 12          513    Mark    Finance                 8    82.0   33
# ...

# %%
# 1. Plot a histogram for Salary
plt.figure(figsize=(8,6))
sns.histplot(emp['Salary'], bins=8, kde=True, color='skyblue')
plt.title("Salary Distribution")
plt.xlabel("Salary")
plt.ylabel("Frequency")
plt.show()

# %%
# 2. Draw a box plot for Age
plt.figure(figsize=(6,5))
sns.boxplot(y=emp['Age'], color='lightgreen')
plt.title("Box Plot of Age")
plt.ylabel("Age")
plt.show()

# %%
# 3. Create a bar chart showing department-wise employee count
plt.figure(figsize=(7,5))
sns.countplot(x='Department', data=emp, palette='viridis')
plt.title("Department-wise Employee Count")
plt.xlabel("Department")
plt.ylabel("Number of Employees")
plt.show()
# Out:
# C:\Users\samik\AppData\Local\Temp\ipykernel_7552\3567000009.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Department', data=emp, palette='viridis')

# %%
# 4. Plot a scatter plot between Experience and Salary
plt.figure(figsize=(8,6))
sns.scatterplot(x='Experience_Years', y='Salary', hue='Department', data=emp, s=100)
plt.title("Scatter Plot: Experience vs Salary")
plt.xlabel("Experience (Years)")
plt.ylabel("Salary")
plt.show()

# %%
# 5. Display a correlation heatmap
plt.figure(figsize=(8,6))
sns.heatmap(emp[['Experience_Years','Salary','Age']].corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()
