# %%
# Square root of a number
import math

# Input from user
num = float(input("Enter a number: "))
print("Enter a number:", num)

# Square root
result = math.sqrt(num)

# Output
print("Square root of", num, "is:", result)
# Out:
# Enter a number: 16.0
# Square root of 16.0 is: 4.0

# %%
# Factorial of a number
import math

# Input from user
num = int(input("Enter a number: "))
print("Enter a number:", num)

# Factorial
result = math.factorial(num)

# Output
print("Factorial of", num, "is:", result)
# Out:
# Enter a number: 25
# Factorial of 25 is: 15511210043330985984000000

# %%
# Power of a number
import math

# Input from user
base = float(input("Enter the base number: "))
print("Enter the base number:", base)
exponent = float(input("Enter the exponent: "))
print("Enter the exponent:", exponent)

# Power calculation
result = math.pow(base, exponent)

# Output
print(base, "raised to the power", exponent, "is:", result)
# Out:
# Enter the base number: 20.0
# Enter the exponent: 20.0
# 20.0 raised to the power 20.0 is: 1.048576e+26
